# %% [markdown]
# # Q1. 畫出 diamond shape

# %%
def diamond(n):
    
    for i in range(n):
        print ((n-i)*' '+(2*i+1)*'*')
    print((2*n+1)*'*')
    for i in range(n):
        print ((i+1)*' '+(2*n-2*i-1)*'*')
    for i in range(n):
        print ((n-i)*'*'+(2*i+1)*' '+(n-i)*'*')
    print((2*n+1)*' ')
    for i in range(n):
        print ((i+1)*'*'+(2*n-2*i-1)*' '+(i+1)*'*')
    for i in range(n):
        print ((n-i)*' '+'*'+(2*i-1)*' '+'*'*min(i,1))
    print('*'+(2*n-1)*' '+'*')
    for i in range(n):
        print ((i+1)*' '+'*'+(2*n-2*i-3)*' '+'*'*min(n-i-1,1))

# %%
diamond(5)
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
# ***********
#  *********
#   *******
#    *****
#     ***
#      *
# ***** *****
# ****   ****
# ***     ***
# **       **
# *         *
#
# *         *
# **       **
# ***     ***
# ****   ****
# ***** *****
#      *
#     * *
#    *   *
#   *     *
#  *       *
# *         *
#  *       *
#   *     *
#    *   *
#     * *
#      *

# %% [markdown]
# # Q2. 刪除重複性的資料。

# %%
import numpy as np

# %%
lst1 = [line.strip('\n') for line in open('symbols01.txt')]
lst2 = [line.strip('\n') for line in open('symbols02.txt')]

# %%
lst3 = lst1 + lst2

# %%
uni = np.unique(lst3)

# %%
str1 = '\r'.join(uni)

# %%
with open("symbols03.txt", "w") as output:
    output.write(str1)

# %% [markdown]
# # Q3. 下載台灣上市公司基本資料。

# %%
import requests
from io import StringIO
import pandas as pd

# %%
url = 'http://dts.twse.com.tw/opendata/t187ap03_L.csv'

# %%
r = requests.get(url)

# %%
r.encoding = 'big5'

# %%
datas=StringIO(r.text)
df1 = pd.read_csv(datas,skiprows=1)

# %%
df1.head()
# Out:
#             公司代號  公司名稱                     產業別          住址 營利事業統一編號  董事長  總經理  \
# 1101  台灣水泥股份有限公司  水泥工業           台北市中山北路2段113號  11913502.0      張安平  李鐘培  黃健強
# 1102  亞洲水泥股份有限公司  水泥工業  台北市大安區敦化南路2段207號30、31樓   3244509.0      徐旭東  李坤炎  周維崑
# 1103  嘉新水泥股份有限公司  水泥工業            台北市中山北路2段96號  11892801.0      張剛綸  祁士鉅  王立心
# 1104  環球水泥股份有限公司  水泥工業        台北市南京東路二段125號10樓   7568009.0      侯博義  侯博義  楊宗仁
# 1108  幸福水泥股份有限公司  水泥工業           台北市松江路237號15樓  40601248.0      陳兩傳  陳兩傳  溫秀菊
#
#          發言人 發言人職稱          代理發言人 ...  特別股         編制財務報表類型         股票過戶機構  \
# 1101  資深副總經理   蔡立文  (02)2531-7099 ...  1.0      中國信託商業銀行代理部       66365566
# 1102    副總經理   吳玲綾   02-2733-8000 ...  1.0       亞東證券股份有限公司   02-2361-8608
# 1103  執行副總經理   余曉芸  (02)2551-5211 ...  1.0  群益金鼎證券股份有限公司股代部  (02)2702-3999
# 1104      經理   詹志鴻    02-25077801 ...  1.0  凱基證券股份有限公司股務代理部    02-23892999
# 1108   財務部經理   陳一誠       25092188 ...  1.0        永豐金證券股務代理      2381-6288
#
#                     過戶電話          過戶地址  \
# ...

# %% [markdown]
# ## Q3. 畫出技術曲線

# %%
import pickle
import talib
# %matplotlib notebook

# %%
# 讀出預先下載好的股價資料
with open('stockdata', 'rb') as f:
    data = pickle.load(file=f)

# %%
df = data['GOOG']
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-12-31  769.500000  769.500000  758.340027  758.880005  758.880005
# 2016-01-04  743.000000  744.059998  731.257996  741.840027  741.840027
# 2016-01-05  746.450012  752.000000  738.640015  742.580017  742.580017
# 2016-01-06  730.000000  747.179993  728.919983  743.619995  743.619995
# 2016-01-07  730.309998  738.500000  719.059998  726.390015  726.390015
#
#              Volume  RSI  signals  positions  Talib_K_index  ...    \
# Date                                                         ...
# 2015-12-31  1500900  NaN        0        NaN            NaN  ...
# 2016-01-04  3272800  NaN        0        0.0            NaN  ...
# 2016-01-05  1950700  NaN        0        0.0            NaN  ...
# 2016-01-06  1947000  NaN        0        0.0            NaN  ...
# 2016-01-07  2963700  NaN        0        0.0            NaN  ...
#
# ...

# %%
df['SAR'] = talib.SAR(df.High.values,df.Low.values,0.01)
df['SAREXT'] = abs(talib.SAREXT(df.High.values,df.Low.values))
df['EMA10'] = talib.EMA(df.Close.values,timeperiod=10)
df['SMA10'] = talib.SMA(df.Close.values,timeperiod=10)

# %%
len(df.Low.values)
# Out:
# 487

# %%
df['SAREXT_pct'] = df.SAREXT.pct_change() 
df['KAMA'] = talib.KAMA(df.Close.values,timeperiod=30)

# %%
df[['Close','KAMA','EMA10','SMA10']].plot(legend='best', figsize=(10,8))
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Q5. 策略回測

# %%
import numpy as np
import ffn
from talib import MA_Type
import pandas as pd

# %%
# 計算 MaxDD
def DrawDownAnalysis(cumRet):
    dd_series = ffn.core.to_drawdown_series(cumRet)
    dd_details = ffn.core.drawdown_details(dd_series)
    return dd_details['drawdown'].min(), dd_details['days'].max()

# %%
# 利用策略產生的持有部位資訊，計算底下四個指標來判斷投資績效
# sharpe ratio: 判斷報酬的好壞跟穩定度，數值越大越好
# maxdd: maximum drawdown, 最糟糕的狀況會賠幾 %
# maxddd: maximum drawdown duration, 低於上一次最高報酬的天數
# cumRet[-1]: 最後賺的 % 數

def indicators(df):
    dailyRet = df['Close'].pct_change()
    excessRet = (dailyRet - 0.04/252)[df['positions'] == 1]
    SharpeRatio = np.sqrt(252.0)*np.mean(excessRet)/np.std(excessRet)
    
    cumRet = np.cumprod(1+excessRet)
    
    maxdd, maxddd = DrawDownAnalysis(cumRet)
    
    return SharpeRatio, maxdd, maxddd, cumRet[-1]

# %%
# 這是我們的策略的部分
# 主要只是要算出進出的訊號 signals 跟何時持有部位 positions
# 底下是一個突破系統的範例

def Breakout_strategy(df):
    # Donchian Channel
    df['20d_high'] = np.round(pd.Series.rolling(df['Close'], window=20).max(), 2)
    df['10d_low'] = np.round(pd.Series.rolling(df['Close'], window=10).min(), 2)

    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['Close'][t] > df['20d_high'][t-1]:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['Close'][t] < df['10d_low'][t-1]:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def RSI_7030_strategy(df):
    df['RSI'] = talib.RSI(df['Close'].values)
    
    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['RSI'][t-1] < 30:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['RSI'][t-1] > 70:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def BBands_strategy(df):
    df['UBB'], df['MBB'], df['LBB'] = talib.BBANDS(df['Close'].values, matype=MA_Type.T3)

    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['Close'][t] < df['LBB'][t-1]:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['Close'][t] > df['UBB'][t-1]:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
# 定義你的策略

def M064030028_strategy(df):

    df['EMA'] = talib.EMA(df.Close.values,timeperiod=20)
    df['SMA'] = talib.SMA(df.Close.values,timeperiod=20)
    df['KAMA'] = talib.KAMA(df.Close.values,timeperiod=30)
    
    has_position = False
    df['signals'] = 0
    for t in range(2,df['signals'].size):
        if df['EMA'][t] > df['SMA'][t] and df['EMA'][t] < df['KAMA'][t]:
            if not has_position:
                df.loc[df.index[t] ,"signals"]=1
                has_position =True
        elif df['EMA10'][t] < df['KAMA'][t] :
            if has_position:
                df.loc[df.index[t],'signals']= -1
                has_position = False
                
    # TODO
    # 填入你們的策略

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def Buy_and_Hold(df):

    has_position = False
    df['signals'] = 0
    for t in range(2,df['signals'].size):
        if has_position == False:
            if not has_position:
                df.loc[df.index[t] ,"signals"]=1
                has_position =True
        elif t == len(df) :
            if has_position:
                df.loc[df.index[t],'signals']= -1
                has_position = False
                
    # TODO
    # 填入你們的策略

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def apply_strategy(strategy, df):
    return strategy(df)

# %%
# 計算各支股票的回測結果
results = []

strategies = [Breakout_strategy, RSI_7030_strategy, BBands_strategy , M064030028_strategy, Buy_and_Hold]

for symbol in data:
    for strategy in strategies:
        try:
            apply_strategy(strategy, data[symbol])
            if np.all(data[symbol]['signals']==0):
                print("Symbol:", symbol, "使用", strategy.__name__, "策略沒有出現買賣訊號。")
                continue
            SharpeRatio, maxdd, maxddd, finalRet = indicators(data[symbol])
            days = (data[symbol].index[-1] - data[symbol].index[0]).days
            results.append((SharpeRatio, maxdd, maxddd, finalRet, days,
                            data[symbol][data[symbol]['signals'] > 0]['signals'].sum(), symbol, strategy.__name__))
        except Exception as e:
            print("Error occurs at symbol:", symbol, "Strategy:", strategy.__name__, "==>", e.args)

# %%
results_df = pd.DataFrame(results, columns=['sharpe','MaxDrawDown','MaxDrawDownDuration','returns', 
                                            'days', 'entries','symbol','strategy'])

# %%
results_df.head()
# Out:
#      sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries symbol  \
# 0  0.131503    -0.208296                  281  0.995734   705       11   TICC
# 1  0.395515    -0.244817                  482  1.077756   705        2   TICC
# 2  0.102787    -0.231763                  426  0.984521   705       20   TICC
# 3  0.541139    -0.357342                  281  1.199307   705        1   TICC
# 4  0.052115    -0.357342                  281  0.938178   705        1   TICC
#
#               strategy
# 0    Breakout_strategy
# 1    RSI_7030_strategy
# 2      BBands_strategy
# 3  M064030028_strategy
# 4         Buy_and_Hold

# %%
results_df.sort_values('MaxDrawDownDuration',ascending=False).head()
# Out:
#        sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries  \
# 54  -0.337218    -0.822166                  698  0.225632   705        1
# 69  -0.572864    -0.602250                  698  0.398612   705        1
# 10  -0.031885    -0.316309                  633  0.922493   705       13
# 130 -0.125746    -0.369419                  623  0.927183   705        9
# 7   -0.048164    -0.418071                  615  0.898925   705       21
#
#     symbol           strategy
# 54    NLNK       Buy_and_Hold
# 69    GERN       Buy_and_Hold
# 10    AMOT  Breakout_strategy
# 130    VRA  Breakout_strategy
# 7     TWIN    BBands_strategy

# %%
results_df.sort_values('returns',ascending=False).head()
# Out:
#       sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries  \
# 33  2.321962    -0.157591                   88  3.424481   705        1
# 98  1.322788    -0.493953                  223  3.082480   705        1
# 34  1.908373    -0.215336                   97  2.928111   705        1
# 99  1.189289    -0.493953                  223  2.871603   705        1
# 18  1.277480    -0.400052                  215  2.560731   705        1
#
#    symbol             strategy
# 33   RICK  M064030028_strategy
# 98   BBGI  M064030028_strategy
# 34   RICK         Buy_and_Hold
# 99   BBGI         Buy_and_Hold
# 18   CDZI  M064030028_strategy

# %%
results_df.sort_values('sharpe',ascending=False).head()
# Out:
#        sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries  \
# 17  10.243474    -0.006251                    3  1.132402   705        1
# 21   7.010574    -0.034481                   16  1.118930   705        1
# 77   6.525037    -0.049054                   66  1.417397   705        2
# 73   6.306176    -0.003654                  122  1.028222   473        3
# 37   4.202639    -0.031822                   16  1.068818   203        1
#
#    symbol           strategy
# 17   GOOG  RSI_7030_strategy
# 21   TBNK  RSI_7030_strategy
# 77   BBGI  RSI_7030_strategy
# 73    LCA  RSI_7030_strategy
# 37   CSML  RSI_7030_strategy

# %%
print("TR of My Strategy: ",sum(results_df[results_df['strategy'] == 'M064030028_strategy'].returns))
print("TR of RSI Strategy: ",sum(results_df[results_df['strategy'] == 'RSI_7030_strategy'].returns))
print("TR of BBands Strategy: ",sum(results_df[results_df['strategy'] == 'BBands_strategy'].returns))
print("TR of BO Strategy: ",sum(results_df[results_df['strategy'] == 'Breakout_strategy'].returns))
print("TR of BH Strategy: ",sum(results_df[results_df['strategy'] == 'Buy_and_Hold'].returns))
# Out:
# TR of My Strategy:  39.6913452145
# TR of RSI Strategy:  36.4452440629
# TR of BBands Strategy:  35.3409730113
# TR of BO Strategy:  32.0725696472
# TR of BH Strategy:  37.0846302064

# %% [markdown]
# ## 這邊有個有趣的結論，在資料期間，事實上閉著眼睛買所有股票(類似Benchmark)，可以獲得比大部分技術分析(除了我的 :p)有更高的Return
